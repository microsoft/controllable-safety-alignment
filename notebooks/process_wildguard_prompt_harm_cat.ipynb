# %%
import os
os.chdir('..')
os.getcwd()

# %%
from datasets import load_from_disk, Dataset, DatasetDict
from collections import Counter, defaultdict
from src.produce_metrics import raw_harmcategorization_to_cat_str

# %%
ds = load_from_disk('data/prompt/wg_non_adv_prompts_l3_64_ds_model-gpt-4o_harmcat_prompt_e7+1_gr')
ds
# Out:
# Dataset({
#     features: ['prompt', 'prompt_harm_categorization_response'],
#     num_rows: 23511
# })

# %%
counter = Counter()
cat2prompt = defaultdict(list)
for ex in ds:
    raw_gpt_response = ex['prompt_harm_categorization_response']
    cat_str = raw_harmcategorization_to_cat_str(raw_gpt_response)
    counter[cat_str] += 1
    cat2prompt[cat_str].append(ex['prompt'])
counter
# Out:
# Counter({'--': 11320,
#          '-Discrimination and Verbal Abuse-': 2387,
#          '-Other Harms-': 1185,
#          '-Financial Crime and Theft-Privacy Violations-': 1106,
#          '-Privacy Violations-': 1032,
#          '-Financial Crime and Theft-': 950,
#          '-Discrimination and Verbal Abuse-Other Harms-': 841,
#          '-Violence-Other Harms-': 537,
#          'INVALID': 518,
#          '-Sexual Misconduct, Exploitation, and Infidelity-': 344,
#          '-Violence-': 303,
#          '-Illegal Drug-Related Activities and Substance Abuse-': 281,
#          '-Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 255,
#          '-Discrimination and Verbal Abuse-Violence-Other Harms-': 229,
#          '-Financial Crime and Theft-Privacy Violations-Other Harms-': 206,
#          '-Privacy Violations-Other Harms-': 182,
#          '-Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 147,
#          '-Financial Crime and Theft-Other Harms-': 133,
#          '-Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-': 132,
#          '-Discrimination and Verbal Abuse-Violence-': 118,
#          '-Discrimination and Verbal Abuse-Privacy Violations-Other Harms-': 101,
#          '-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 87,
#          '-Illegal Drug-Related Activities and Substance Abuse-Other Harms-': 80,
#          '-Violence-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 68,
#          '-Discrimination and Verbal Abuse-Sexual Misconduct, Exploitation, and Infidelity-': 68,
#          '-Violence-Sexual Misconduct, Exploitation, and Infidelity-': 52,
#          '-Violence-Privacy Violations-Other Harms-': 46,
#          '-Discrimination and Verbal Abuse-Violence-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 43,
#          '-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-': 43,
#          '-Discrimination and Verbal Abuse-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 40,
#          '-Financial Crime and Theft-Violence-Other Harms-': 39,
#          '-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 38,
#          '-Violence-Illegal Drug-Related Activities and Substance Abuse-Other Harms-': 36,
#          '-Financial Crime and Theft-Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 33,
#          '-Discrimination and Verbal Abuse-Privacy Violations-': 32,
#          '-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 32,
#          '-Discrimination and Verbal Abuse-Violence-Privacy Violations-Other Harms-': 26,
#          '-Discrimination and Verbal Abuse-Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 24,
#          '-Financial Crime and Theft-Violence-Privacy Violations-Other Harms-': 23,
#          '-Financial Crime and Theft-Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 23,
#          '-Violence-Privacy Violations-': 22,
#          '-Discrimination and Verbal Abuse-Violence-Sexual Misconduct, Exploitation, and Infidelity-': 22,
#          '-Violence-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 20,
#          '-Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-': 19,
#          '-Financial Crime and Theft-Violence-': 19,
#          '-Financial Crime and Theft-Violence-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 17,
#          '-Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-Other Harms-': 15,
#          '-Financial Crime and Theft-Violence-Privacy Violations-': 12,
#          '-Financial Crime and Theft-Violence-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 12,
#          '-Discrimination and Verbal Abuse-Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 11,
#          '-Violence-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 11,
#          '-Violence-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 11,
#          '-Financial Crime and Theft-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 10,
#          '-Violence-Illegal Drug-Related Activities and Substance Abuse-': 10,
#          '-Discrimination and Verbal Abuse-Violence-Privacy Violations-': 8,
#          '-Discrimination and Verbal Abuse-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 8,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-Privacy Violations-Other Harms-': 7,
#          '-Financial Crime and Theft-Violence-Illegal Drug-Related Activities and Substance Abuse-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 7,
#          '-Illegal Drug-Related Activities and Substance Abuse-Sexual Misconduct, Exploitation, and Infidelity-': 7,
#          '-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 7,
#          '-Violence-Illegal Drug-Related Activities and Substance Abuse-Sexual Misconduct, Exploitation, and Infidelity-': 7,
#          '-Financial Crime and Theft-Violence-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 6,
#          '-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-': 6,
#          '-Financial Crime and Theft-Violence-Illegal Drug-Related Activities and Substance Abuse-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 5,
#          '-Financial Crime and Theft-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-': 5,
#          '-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-Other Harms-': 5,
#          '-Discrimination and Verbal Abuse-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-': 5,
#          '-Violence-Illegal Drug-Related Activities and Substance Abuse-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 4,
#          '-Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 4,
#          '-Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 4,
#          '-Illegal Drug-Related Activities and Substance Abuse-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 4,
#          '-Financial Crime and Theft-Violence-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 3,
#          '-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 3,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-Violence-Other Harms-': 3,
#          '-Discrimination and Verbal Abuse-Violence-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 3,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-Violence-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 3,
#          '-Financial Crime and Theft-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 3,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-': 3,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-Privacy Violations-': 2,
#          '-Violence-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-': 2,
#          '-Financial Crime and Theft-Violence-Illegal Drug-Related Activities and Substance Abuse-Other Harms-': 2,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-Violence-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 2,
#          '-Violence-Illegal Drug-Related Activities and Substance Abuse-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 2,
#          '-Financial Crime and Theft-Violence-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-Other Harms-': 2,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-Other Harms-': 2,
#          '-Violence-Illegal Drug-Related Activities and Substance Abuse-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 2,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 2,
#          '-Financial Crime and Theft-Sexual Misconduct, Exploitation, and Infidelity-': 2,
#          '-Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 2,
#          '-Financial Crime and Theft-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 1,
#          '-Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 1,
#          '-Violence-Sexual Misconduct, Exploitation, and Infidelity-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 1,
#          '-Discrimination and Verbal Abuse-Violence-Illegal Drug-Related Activities and Substance Abuse-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-': 1,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-Illegal Drug-Related Activities and Substance Abuse-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 1,
#          '-Discrimination and Verbal Abuse-Violence-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-': 1,
#          '-Financial Crime and Theft-Violence-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-': 1,
#          '-Discrimination and Verbal Abuse-Violence-Sexual Misconduct, Exploitation, and Infidelity-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 1,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-Violence-Privacy Violations-': 1,
#          '-Illegal Drug-Related Activities and Substance Abuse-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 1,
#          '-Financial Crime and Theft-Violence-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 1,
#          '-Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 1,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-Violence-Privacy Violations-Other Harms-': 1,
#          '-Financial Crime and Theft-Discrimination and Verbal Abuse-Illegal Drug-Related Activities and Substance Abuse-Other Harms-': 1,
#          '-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 1,
#          '-Financial Crime and Theft-Violence-Illegal Drug-Related Activities and Substance Abuse-Sexual Misconduct, Exploitation, and Infidelity-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-': 1,
#          '-Violence-Sexual Misconduct, Exploitation, and Infidelity-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 1,
#          '-Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-': 1})

# %%
import random
cat2prompt_subsample = {k: random.sample(v, min(len(v), 2500)) for k, v in cat2prompt.items()}
print(f'total number of prompts: {sum(len(v) for v in cat2prompt_subsample.values())}')
# Out:
# total number of prompts: 14691

# %%
ddict = DatasetDict({k: Dataset.from_dict({'prompt': v}) for k, v in cat2prompt_subsample.items() if not (k in ['-Financial Crime and Theft-Discrimination and Verbal Abuse-Violence-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-', 'INVALID']) and len(v) > 10})
ddict
# Out:
# DatasetDict({
#     -Financial Crime and Theft-: Dataset({
#         features: ['prompt'],
#         num_rows: 950
#     })
#     -Financial Crime and Theft-Privacy Violations-: Dataset({
#         features: ['prompt'],
#         num_rows: 1106
#     })
#     --: Dataset({
#         features: ['prompt'],
#         num_rows: 2500
#     })
#     -Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 1185
#     })
#     -Discrimination and Verbal Abuse-: Dataset({
#         features: ['prompt'],
#         num_rows: 2387
#     })
#     -Illegal Drug-Related Activities and Substance Abuse-: Dataset({
#         features: ['prompt'],
#         num_rows: 281
#     })
#     -Privacy Violations-: Dataset({
#         features: ['prompt'],
#         num_rows: 1032
#     })
#     -Discrimination and Verbal Abuse-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 841
#     })
#     -Sexual Misconduct, Exploitation, and Infidelity-: Dataset({
#         features: ['prompt'],
#         num_rows: 344
#     })
#     -Privacy Violations-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 182
#     })
#     -Violence-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 537
#     })
#     -Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 38
#     })
#     -Financial Crime and Theft-Violence-Privacy Violations-: Dataset({
#         features: ['prompt'],
#         num_rows: 12
#     })
#     -Violence-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 68
#     })
#     -Financial Crime and Theft-Privacy Violations-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 206
#     })
#     -Financial Crime and Theft-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 133
#     })
#     -Discrimination and Verbal Abuse-Sexual Misconduct, Exploitation, and Infidelity-: Dataset({
#         features: ['prompt'],
#         num_rows: 68
#     })
#     -Sexual Misconduct, Exploitation, and Infidelity-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 87
#     })
#     -Violence-: Dataset({
#         features: ['prompt'],
#         num_rows: 303
#     })
#     -Discrimination and Verbal Abuse-Violence-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 229
#     })
#     -Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 147
#     })
#     -Financial Crime and Theft-Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-: Dataset({
#         features: ['prompt'],
#         num_rows: 33
#     })
#     -Discrimination and Verbal Abuse-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 40
#     })
#     -Illegal Drug-Related Activities and Substance Abuse-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 80
#     })
#     -Violence-Privacy Violations-: Dataset({
#         features: ['prompt'],
#         num_rows: 22
#     })
#     -Discrimination and Verbal Abuse-Violence-: Dataset({
#         features: ['prompt'],
#         num_rows: 118
#     })
#     -Violence-Illegal Drug-Related Activities and Substance Abuse-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 36
#     })
#     -Discrimination and Verbal Abuse-Violence-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 43
#     })
#     -Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-: Dataset({
#         features: ['prompt'],
#         num_rows: 255
#     })
#     -Discrimination and Verbal Abuse-Privacy Violations-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 101
#     })
#     -Discrimination and Verbal Abuse-Privacy Violations-: Dataset({
#         features: ['prompt'],
#         num_rows: 32
#     })
#     -Financial Crime and Theft-Violence-Privacy Violations-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 23
#     })
#     -Discrimination and Verbal Abuse-Violence-Privacy Violations-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 26
#     })
#     -Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-: Dataset({
#         features: ['prompt'],
#         num_rows: 132
#     })
#     -Financial Crime and Theft-Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 23
#     })
#     -Violence-Sexual Misconduct, Exploitation, and Infidelity-: Dataset({
#         features: ['prompt'],
#         num_rows: 52
#     })
#     -Discrimination and Verbal Abuse-Violence-Sexual Misconduct, Exploitation, and Infidelity-: Dataset({
#         features: ['prompt'],
#         num_rows: 22
#     })
#     -Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-Privacy Violations-: Dataset({
#         features: ['prompt'],
#         num_rows: 19
#     })
#     -Financial Crime and Theft-Violence-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 12
#     })
#     -Financial Crime and Theft-Violence-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 39
#     })
#     -Discrimination and Verbal Abuse-Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 24
#     })
#     -Violence-Privacy Violations-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 46
#     })
#     -Financial Crime and Theft-Violence-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-: Dataset({
#         features: ['prompt'],
#         num_rows: 17
#     })
#     -Weapons, Explosives, Arson, and Illegal Firearm Transactions-: Dataset({
#         features: ['prompt'],
#         num_rows: 32
#     })
#     -Discrimination and Verbal Abuse-Violence-Weapons, Explosives, Arson, and Illegal Firearm Transactions-: Dataset({
#         features: ['prompt'],
#         num_rows: 11
#     })
#     -Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-: Dataset({
#         features: ['prompt'],
#         num_rows: 43
#     })
#     -Violence-Privacy Violations-Sexual Misconduct, Exploitation, and Infidelity-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 20
#     })
#     -Violence-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-: Dataset({
#         features: ['prompt'],
#         num_rows: 11
#     })
#     -Financial Crime and Theft-Illegal Drug-Related Activities and Substance Abuse-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 15
#     })
#     -Financial Crime and Theft-Violence-: Dataset({
#         features: ['prompt'],
#         num_rows: 19
#     })
#     -Violence-Privacy Violations-Weapons, Explosives, Arson, and Illegal Firearm Transactions-Other Harms-: Dataset({
#         features: ['prompt'],
#         num_rows: 11
#     })
# })

# %%
save_path = 'data/by_spec/wg_non_adv_prompts/gpt-4o_label'
ddict.save_to_disk(save_path)
# Out:
# Saving the dataset (1/1 shards): 100%|██████████| 950/950 [00:00<00:00, 193737.00 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 1106/1106 [00:00<00:00, 247672.20 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2500/2500 [00:00<00:00, 512675.89 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 1185/1185 [00:00<00:00, 286304.74 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2387/2387 [00:00<00:00, 514454.74 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 281/281 [00:00<00:00, 68819.31 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 1032/1032 [00:00<00:00, 231769.21 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 841/841 [00:00<00:00, 195446.01 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 344/344 [00:00<00:00, 85725.18 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 182/182 [00:00<00:00, 44119.95 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 537/537 [00:00<00:00, 85096.77 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 38/38 [00:00<00:00, 10292.77 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 12/12 [00:00<00:00, 3175.50 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 68/68 [00:00<00:00, 18702.47 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 206/206 [00:00<00:00, 54059.10 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 133/133 [00:00<00:00, 35073.40 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 68/68 [00:00<00:00, 19186.86 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 87/87 [00:00<00:00, 23184.73 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 303/303 [00:00<00:00, 84674.14 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 229/229 [00:00<00:00, 61162.48 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 147/147 [00:00<00:00, 38726.38 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 33/33 [00:00<00:00, 8440.79 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 40/40 [00:00<00:00, 10147.10 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 80/80 [00:00<00:00, 22056.42 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 22/22 [00:00<00:00, 5990.31 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 118/118 [00:00<00:00, 32685.77 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 36/36 [00:00<00:00, 8811.05 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 43/43 [00:00<00:00, 10692.14 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 255/255 [00:00<00:00, 68829.88 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 101/101 [00:00<00:00, 27089.44 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 32/32 [00:00<00:00, 8218.59 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 23/23 [00:00<00:00, 5750.42 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 26/26 [00:00<00:00, 6552.02 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 132/132 [00:00<00:00, 33899.59 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 23/23 [00:00<00:00, 5480.26 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 52/52 [00:00<00:00, 14504.48 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 22/22 [00:00<00:00, 5415.82 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 19/19 [00:00<00:00, 4930.20 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 12/12 [00:00<00:00, 3258.56 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 39/39 [00:00<00:00, 9753.03 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 24/24 [00:00<00:00, 6688.15 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 46/46 [00:00<00:00, 11686.13 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 17/17 [00:00<00:00, 4010.08 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 32/32 [00:00<00:00, 8516.35 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 11/11 [00:00<00:00, 2799.26 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 43/43 [00:00<00:00, 12440.85 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 5534.11 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 11/11 [00:00<00:00, 2819.44 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 15/15 [00:00<00:00, 3887.45 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 19/19 [00:00<00:00, 4810.56 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 11/11 [00:00<00:00, 2787.08 examples/s]
